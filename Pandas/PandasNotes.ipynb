# %%
import pandas as pd          #import pandas as alias pd

# %%
mycars = {
    'Cars':['BMW', 'TATA', 'Maruti', 'Volvo'],
    'Price':[1000, 1002, 5000, 10000]
}

# %%
myvar = pd.DataFrame(mycars)

# %%
print(myvar)
# Out:
#      Cars  Price
# 0     BMW   1000
# 1    TATA   1002
# 2  Maruti   5000
# 3   Volvo  10000

# %%
print(pd.__version__)   #to check version
# Out:
# 1.3.4

# %%
#simple pandas series from list
#A Pandas Series is like a column in a table.

a = [1, 7, 2]

myvar = pd.Series(a)

print(myvar)
# Out:
# 0    1
# 1    7
# 2    2
# dtype: int64

# %%
print(myvar[1])
# Out:
# 7

# %%
#create own labels as
#labels are nothing but index

a = [2,4,6,8]
mt = pd.Series(a, index = ["w", "x", "y", "z"])

# %%
print(mt["y"])
# Out:
# 6

# %%
#Data sets in Pandas are usually multi-dimensional tables, called DataFrames.
#Series is like a column, a DataFrame is the whole table.
import pandas as pd
m = {
    'Name':['Ankita', 'Pankaj', 'Adi', 'Mau', 'Gitu', 'Dubri'],
    'Age':[26, 29, 28, 23, 23, 24]
}
mt = pd.DataFrame(m)
print(mt)
# Out:
#      Name  Age
# 0  Ankita   26
# 1  Pankaj   29
# 2     Adi   28
# 3     Mau   23
# 4    Gitu   23
# 5   Dubri   24

# %%
#Pandas use the loc attribute to return one or more specified row(s)

#refer to the row index:
print(mt.loc[3])
# Out:
# Name    Mau
# Age      23
# Name: 3, dtype: object

# %%
print(mt.loc[0:3,['Age','Name']])
# Out:
#    Age    Name
# 0   26  Ankita
# 1   29  Pankaj
# 2   28     Adi
# 3   23     Mau

# %%
print(mt.loc[[1,4,1]])
# Out:
#      Name  Age
# 1  Pankaj   29
# 4    Gitu   23
# 1  Pankaj   29

# %%
#different ways to create dataframes

# %%
#by using csv
df = pd.read_csv('titanic.csv')
print(df)
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
#to check type
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
#to check no of rows and columns
df.shape
# Out:
# (891, 12)

# %%
#how to pass list/tuple as dataframe
import pandas as pd
Emp = [
    (1, 'Ankita', 26),
    (2, 'Pankaj', 30),
    (3, 'Madhu', 23),
    (4, 'Aditya', 28)
]

df2 = pd.DataFrame(data = Emp, columns = ['Id', 'Name', 'Age'])
print(df2)
# Out:
#    Id    Name  Age
# 0   1  Ankita   26
# 1   2  Pankaj   30
# 2   3   Madhu   23
# 3   4  Aditya   28

# %%
#how to pass list/tuple as dataframe with column names
import pandas as pd
Emp = [
    [1, 'Ankita', 26, 'Pune'],
    [2, 'Pankaj', 30, 'Raigad'],
    [3, 'Madhu', 23, 'Haridwar'],
    [4, 'Adi', 28, 'Malegaon']
]

df2 = pd.DataFrame(data = Emp, columns = ['ID', 'Name', 'Age', 'City'])
print(df2)
# Out:
#    ID    Name  Age      City
# 0   1  Ankita   26      Pune
# 1   2  Pankaj   30    Raigad
# 2   3   Madhu   23  Haridwar
# 3   4     Adi   28  Malegaon

# %%
#how to pass Dict as dataframe
import pandas as pd
Product = [
    {'Name':'Iron', 'Id':501, 'Price':5000, 'Quantity': 10000},
    {'Name':'Gold', 'Id':110, 'Price':9050, 'Quantity': 60000},    
    {'Name':'Silver', 'Id':321, 'Price':2060, 'Quantity': 30000},
    {'Name':'Aluminium', 'Id':467, 'Price':1000, 'Quantity': 70000},
    {'Name':'Copper', 'Id':235, 'Price':500, 'Quantity': 80000},
    {'Name':'Brass', 'Id':789, 'Price':5670, 'Quantity': 90000},
    {'Name':'Platinum', 'Id':990, 'Price':2300, 'Quantity': 20000, 'Expiry':'April 2024'},
]
df3 = pd.DataFrame(Product)
print(df3)
#keys are formed as column names
#extra keys will be given value but rest rows will be NaN
# Out:
#         Name   Id  Price  Quantity      Expiry
# 0       Iron  501   5000     10000         NaN
# 1       Gold  110   9050     60000         NaN
# 2     Silver  321   2060     30000         NaN
# 3  Aluminium  467   1000     70000         NaN
# 4     Copper  235    500     80000         NaN
# 5      Brass  789   5670     90000         NaN
# 6   Platinum  990   2300     20000  April 2024

# %%
#how to read Html
df3 = pd.read_html('https://en.wikipedia.org/wiki/COVID-19_pandemic_by_country_and_territory')
df4 = df3[12]

# %%
df4
# Out:
#                                             Unnamed: 0  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 214                                                NaN
# 215                                                NaN
# 216                                                NaN
# 217                                                NaN
# 218  .mw-parser-output .reflist{font-size:90%;margi...
#
#                                                Country  \
# 0                                             World[a]
# 1                                                 Peru
# 2                                             Bulgaria
# 3                               Bosnia and Herzegovina
# ...

# %%
#to change data to csv
df4.to_csv('corona.csv', index = False)

# %%
#to change data to excel
df4.to_csv('corona.xls', index = False)

# %%
#to change data to dict then dump to json
df5 = df4.to_dict()
import json
js = json.dumps(df5)
with open('corona.json', 'w') as fp:
    json.dump(df5,fp)

# %%
#to change data to json
df4.to_json('c.json')

# %%
help(pd)
# Out:
# Help on package pandas:
#
# NAME
#     pandas
#
# DESCRIPTION
#     pandas - a powerful data analysis and manipulation library for Python
# ...
#
#     **pandas** is a Python package providing fast, flexible, and expressive data
#     structures designed to make working with "relational" or "labeled" data both
#     easy and intuitive. It aims to be the fundamental high-level building block for
#     doing practical, **real world** data analysis in Python. Additionally, it has
#     the broader goal of becoming **the most powerful and flexible open source data
#     analysis / manipulation tool available in any language**. It is already well on
#     its way toward this goal.
#
#     Main Features
#     -------------
#     Here are just a few of the things that pandas does well:
#
#       - Easy handling of missing data in floating point as well as non-floating
#         point data.
#       - Size mutability: columns can be inserted and deleted from DataFrame and
# ...

# %%
#how to check datatypes of columns
df4.dtypes
# Out:
# Unnamed: 0          object
# Country             object
# Deaths / million    object
# Deaths              object
# Cases               object
# dtype: object

# %%
#to fetch 1st 5 rows
df4.head()
# Out:
#   Unnamed: 0                 Country Deaths / million   Deaths      Cases
# 0        NaN                World[a]              806  6351178  555444381
# 1        NaN                    Peru             6405   213685    3675152
# 2        NaN                Bulgaria             5404    37272    1178189
# 3        NaN  Bosnia and Herzegovina             4844    15809     379563
# 4        NaN                 Hungary             4843    46661    1932788

# %%
#to fetch last 5 rows
df4.tail()
# Out:
#                                             Unnamed: 0  \
# 214                                                NaN
# 215                                                NaN
# 216                                                NaN
# 217                                                NaN
# 218  .mw-parser-output .reflist{font-size:90%;margi...
#
#                                                Country  \
# 214                                       Vatican City
# 215                     Federated States of Micronesia
# 216       Saint Helena, Ascension and Tristan da Cunha
# 217                                   Marshall Islands
# 218  .mw-parser-output .reflist{font-size:90%;margi...
#
#                                       Deaths / million  \
# 214                                                  —
# 215                                                  —
# 216                                                  —
# 217                                                  —
# ...

# %%
#to fetch 10 rows from head or tail specify the number in bracket
df4.head(10)
df4.tail(10)
# Out:
#                                             Unnamed: 0  \
# 209                                                NaN
# 210                                                NaN
# 211                                                NaN
# 212                                                NaN
# 213                                                NaN
# 214                                                NaN
# 215                                                NaN
# 216                                                NaN
# 217                                                NaN
# 218  .mw-parser-output .reflist{font-size:90%;margi...
#
#                                                Country  \
# 209                                           China[c]
# 210                                            Burundi
# 211                                              Macau
# 212                                        North Korea
# 213                                   Falkland Islands
# ...

# %%
#to fetch any one column
df4['Country']
# Out:
# 0                                               World[a]
# 1                                                   Peru
# 2                                               Bulgaria
# 3                                 Bosnia and Herzegovina
# 4                                                Hungary
#                              ...
# 214                                         Vatican City
# 215                       Federated States of Micronesia
# 216         Saint Helena, Ascension and Tristan da Cunha
# 217                                     Marshall Islands
# 218    .mw-parser-output .reflist{font-size:90%;margi...
# Name: Country, Length: 219, dtype: object

# %%
#to fetch any multiple columns define column names in list
df4[['Country', 'Cases']]
# Out:
#                                                Country  \
# 0                                             World[a]
# 1                                                 Peru
# 2                                             Bulgaria
# 3                               Bosnia and Herzegovina
# 4                                              Hungary
# ..                                                 ...
# 214                                       Vatican City
# 215                     Federated States of Micronesia
# 216       Saint Helena, Ascension and Tristan da Cunha
# 217                                   Marshall Islands
# 218  .mw-parser-output .reflist{font-size:90%;margi...
#
#                                                  Cases
# 0                                            555444381
# 1                                              3675152
# 2                                              1178189
# 3                                               379563
# ...

# %%
#to fetch all column names
df4.columns
# Out:
# Index(['Unnamed: 0', 'Country', 'Deaths / million', 'Deaths', 'Cases'], dtype='object')

# %%
import pandas as pd
Emp = [
    (1, 'Ankita', 23, 25000, 'Amazon'),
    (2, 'Pankaj', 30, 40000, 'POSCO'),
    (3, 'Madhu', 23, 50000, 'Hero'),
    (4, 'Adi', 28, 80000, 'IBM')
]

df2 = pd.DataFrame(data = Emp, columns = ['ID', 'Name', 'Age', 'Salary','Company'])

# %%
df2
# Out:
#    ID    Name  Age  Salary
# 0   1  Ankita   23   25000
# 1   2  Pankaj   30   40000
# 2   3   Madhu   23   50000
# 3   4     Adi   28   80000

# %%
#to check no of occurance of any unique values
df2['Age'].value_counts()
# Out:
# 23    2
# 30    1
# 28    1
# Name: Age, dtype: int64

# %%
#to check unique values in any column
df2['Age'].unique()
# Out:
# array([23, 30, 28], dtype=int64)

# %%
#to add column
df2['Company'] = 'IBM'

# %%
df2
# Out:
#    ID    Name  Age  Salary Company
# 0   1  Ankita   23   25000     IBM
# 1   2  Pankaj   30   40000     IBM
# 2   3   Madhu   23   50000     IBM
# 3   4     Adi   28   80000     IBM

# %%
df2['Bonus'] = df2['Salary']/2

# %%
df2['Total'] = df2['Salary']+df2['Bonus']
df2
# Out:
#    ID    Name  Age  Salary Company    Bonus     Total
# 0   1  Ankita   23   25000     IBM  12500.0   37500.0
# 1   2  Pankaj   30   40000     IBM  20000.0   60000.0
# 2   3   Madhu   23   50000     IBM  25000.0   75000.0
# 3   4     Adi   28   80000     IBM  40000.0  120000.0

# %%
#to fetch any one row
# fetch using unique value
df2[df2['ID']==3]
# Out:
#    ID   Name  Age  Salary Company    Bonus    Total
# 2   3  Madhu   23   50000     IBM  25000.0  75000.0

# %%
#to delete columns
df2.drop('Total', axis= 1) # this is simple method to delete column
#However, column is not permanantely deleted
# Out:
#    ID    Name  Age  Salary Company    Bonus
# 0   1  Ankita   23   25000     IBM  12500.0
# 1   2  Pankaj   30   40000     IBM  20000.0
# 2   3   Madhu   23   50000     IBM  25000.0
# 3   4     Adi   28   80000     IBM  40000.0

# %%
df2
# Out:
#    ID    Name  Age  Salary Company    Bonus     Total
# 0   1  Ankita   23   25000     IBM  12500.0   37500.0
# 1   2  Pankaj   30   40000     IBM  20000.0   60000.0
# 2   3   Madhu   23   50000     IBM  25000.0   75000.0
# 3   4     Adi   28   80000     IBM  40000.0  120000.0

# %%
#In order to delete the column permanantely we need to save it variable
# but there will be many variable generated
df2 = df2.drop('Total', axis = 1)
df2
# Out:
#    ID    Name  Age  Salary Company    Bonus
# 0   1  Ankita   23   25000     IBM  12500.0
# 1   2  Pankaj   30   40000     IBM  20000.0
# 2   3   Madhu   23   50000     IBM  25000.0
# 3   4     Adi   28   80000     IBM  40000.0

# %%
#Therefore best practice is
df2.drop('Bonus', axis = 1, inplace = True)
df2
# Out:
#    ID    Name  Age  Salary Company
# 0   1  Ankita   23   25000     IBM
# 1   2  Pankaj   30   40000     IBM
# 2   3   Madhu   23   50000     IBM
# 3   4     Adi   28   80000     IBM

# %%
#to delete multiple columns
df2.drop(columns=['Name', 'Age'], axis=1, inplace= True)

# %%
df2
# Out:
#    ID  Salary Company
# 0   1   25000     IBM
# 1   2   40000     IBM
# 2   3   50000     IBM
# 3   4   80000     IBM

# %%
#to delete complete dataframe
del df2

# %%
df2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_13968/3882145664.py in <module>
# ----> 1 df2
#
# NameError: name 'df2' is not defined

# %%
import pandas as pd
df3 = pd.read_csv('HR.csv')

# %%
df3
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
#check unique values
df3['salary'].value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %%
df3.columns
# Out:
# Index(['satisfaction_level', 'last_evaluation', 'number_project',
#        'average_montly_hours', 'time_spend_company', 'Work_accident', 'left',
#        'promotion_last_5years', 'sales', 'salary'],
#       dtype='object')

# %%
df3['number_project'].unique()
# Out:
# array([2, 5, 7, 6, 4, 3], dtype=int64)

# %%
#set user-defined index
df3.set_index('salary', inplace = True)

# %%
df3
# Out:
#         satisfaction_level  last_evaluation  number_project  \
# salary
# low                   0.38             0.53               2
# medium                0.80             0.86               5
# medium                0.11             0.88               7
# low                   0.72             0.87               5
# low                   0.37             0.52               2
# ...                    ...              ...             ...
# low                   0.40             0.57               2
# low                   0.37             0.48               2
# low                   0.37             0.53               2
# low                   0.11             0.96               6
# low                   0.37             0.52               2
#
#         average_montly_hours  time_spend_company  Work_accident  left  \
# salary
# low                      157                   3              0     1
# medium                   262                   6              0     1
# ...

# %%
#to reset index
df3.reset_index()
# Out:
#        salary  satisfaction_level  last_evaluation  number_project  \
# 0         low                0.38             0.53               2
# 1      medium                0.80             0.86               5
# 2      medium                0.11             0.88               7
# 3         low                0.72             0.87               5
# 4         low                0.37             0.52               2
# ...       ...                 ...              ...             ...
# 14994     low                0.40             0.57               2
# 14995     low                0.37             0.48               2
# 14996     low                0.37             0.53               2
# 14997     low                0.11             0.96               6
# 14998     low                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# ...

# %%
import pandas as pd
Emp = [
    ('Ankita', 23, 25000, 'Amazon', 'F'),
    ('Pankaj', 30, 40000, 'POSCO', 'M'),
    ('Madhu', 23, 50000, 'Hero', 'F'),
    ('Adi', 28, 80000, 'IBM', 'M'),
    ('Gitu', 24, 35000, 'Wipro', 'F'),
    ('Nilesh', 22, 18000, 'School', 'M'),
    ('Mau', 18, 15000, 'College', 'F'),
]

df = pd.DataFrame(data = Emp, columns = ['Name', 'Age', 'Salary','Company', 'Gender'])
df['Bonus'] = df['Salary']/2
df['Total'] = df['Salary']+df['Bonus']
df
# Out:
#      Name  Age  Salary  Company Gender    Bonus     Total
# 0  Ankita   23   25000   Amazon      F  12500.0   37500.0
# 1  Pankaj   30   40000    POSCO      M  20000.0   60000.0
# 2   Madhu   23   50000     Hero      F  25000.0   75000.0
# 3     Adi   28   80000      IBM      M  40000.0  120000.0
# 4    Gitu   24   35000    Wipro      F  17500.0   52500.0
# 5  Nilesh   22   18000   School      M   9000.0   27000.0
# 6     Mau   18   15000  College      F   7500.0   22500.0

# %%
#to fetch particular data we use loc and iloc
#df.loc[rows:column]

# %%
#to fetch complete row 2
df.loc[2]
# Out:
# Name         Madhu
# Age             23
# Salary       50000
# Company       Hero
# Gender           F
# Bonus      25000.0
# Total      75000.0
# Name: 2, dtype: object

# %%
#to fetch rows 2 to 5 and columns age and total
df.loc[2:5,['Age', 'Total']]
# Out:
#    Age     Total
# 2   23   75000.0
# 3   28  120000.0
# 4   24   52500.0
# 5   22   27000.0

# %%
#fetch 1st 2 rows
df.loc[:1]
# Out:
#      Name  Age  Salary Company Gender    Bonus    Total
# 0  Ankita   23   25000  Amazon      F  12500.0  37500.0
# 1  Pankaj   30   40000   POSCO      M  20000.0  60000.0

# %%
#fetch rows from 5 to last
df.loc[5:]
# Out:
#      Name  Age  Salary  Company Gender   Bonus    Total
# 5  Nilesh   22   18000   School      M  9000.0  27000.0
# 6     Mau   18   15000  College      F  7500.0  22500.0

# %%
#to fetch range of column you need to specify column as below
df.loc[1:3,'Age':'Bonus']
# Out:
#    Age  Salary Company Gender    Bonus
# 1   30   40000   POSCO      M  20000.0
# 2   23   50000    Hero      F  25000.0
# 3   28   80000     IBM      M  40000.0

# %%
#if you wish to fetch specific columns only
df.loc[1:4,['Name','Salary','Bonus']]
# Out:
#      Name  Salary    Bonus
# 1  Pankaj   40000  20000.0
# 2   Madhu   50000  25000.0
# 3     Adi   80000  40000.0
# 4    Gitu   35000  17500.0

# %%
#fetch column with two step/alternate columns(for alternate columns give step as 2)
df.loc[2:4,'Name':'Total':2]
# Out:
#     Name  Salary Gender     Total
# 2  Madhu   50000      F   75000.0
# 3    Adi   80000      M  120000.0
# 4   Gitu   35000      F   52500.0

# %%
#results with step 3
df.loc[1:2,'Name':'Total':3]
# Out:
#      Name Company    Total
# 1  Pankaj   POSCO  60000.0
# 2   Madhu    Hero  75000.0

# %%
#test- Access Posco
df.loc[1,'Company']
# Out:
# 'POSCO'

# %%
#INTERVIEW QUESTION 
[The .loc[] method is used to retrieve the group of rows and columns by labels or a boolean array present in the DataFrame. 
It takes only index labels, and if it exists in the caller DataFrame, it returns the rows, columns, or DataFrame. 
It is a label-based method but may be used with the boolean array.]

Whereas, the .iloc[] method is used when the index label of the DataFrame is other than 
numeric series of 0,1,2,....,n, or in the case when the user does not know the index label.]

iloc is maximum used as code is not hard coded

# %%
#Let's study iloc
df
# Out:
#      Name  Age  Salary  Company Gender    Bonus     Total
# 0  Ankita   23   25000   Amazon      F  12500.0   37500.0
# 1  Pankaj   30   40000    POSCO      M  20000.0   60000.0
# 2   Madhu   23   50000     Hero      F  25000.0   75000.0
# 3     Adi   28   80000      IBM      M  40000.0  120000.0
# 4    Gitu   24   35000    Wipro      F  17500.0   52500.0
# 5  Nilesh   22   18000   School      M   9000.0   27000.0
# 6     Mau   18   15000  College      F   7500.0   22500.0

# %%
#in iloc name=0, age=1, salary= 2 and so on
#in iloc method name of column is not necessary
#syntax is df.iloc[rowo:rowi, column0:columni], ith column or row is not included
df.iloc[0:3, 0:3]
# Out:
#      Name  Age  Salary
# 0  Ankita   23   25000
# 1  Pankaj   30   40000
# 2   Madhu   23   50000

# %%
#encode
#1. To encode "Gender" column as 0 or 1

df['Encode'] = df['Gender'].map(lambda x: 1 if x=='M' else 0)
df
# Out:
#      Name  Age  Salary  Company Gender    Bonus     Total  Encode
# 0  Ankita   23   25000   Amazon      F  12500.0   37500.0       0
# 1  Pankaj   30   40000    POSCO      M  20000.0   60000.0       1
# 2   Madhu   23   50000     Hero      F  25000.0   75000.0       0
# 3     Adi   28   80000      IBM      M  40000.0  120000.0       1
# 4    Gitu   24   35000    Wipro      F  17500.0   52500.0       0
# 5  Nilesh   22   18000   School      M   9000.0   27000.0       1
# 6     Mau   18   15000  College      F   7500.0   22500.0       0

# %%
df['Profile'] = df['Salary'].map(lambda x: 'Low' if x<=30000 else 'High')
df
# Out:
#      Name  Age  Salary  Company Gender    Bonus     Total  Encode Profile
# 0  Ankita   23   25000   Amazon      F  12500.0   37500.0       0     Low
# 1  Pankaj   30   40000    POSCO      M  20000.0   60000.0       1    High
# 2   Madhu   23   50000     Hero      F  25000.0   75000.0       0    High
# 3     Adi   28   80000      IBM      M  40000.0  120000.0       1    High
# 4    Gitu   24   35000    Wipro      F  17500.0   52500.0       0    High
# 5  Nilesh   22   18000   School      M   9000.0   27000.0       1     Low
# 6     Mau   18   15000  College      F   7500.0   22500.0       0     Low

# %%
N = {
    'Ankita':'A',
    'Pankaj':'P',
    'Nilesh':'N',
    'Adi':'A'
}
df['Initial'] = df['Name'].map(N)
df
# Out:
#      Name  Age  Salary  Company Gender    Bonus     Total  Encode Profile  \
# 0  Ankita   23   25000   Amazon      F  12500.0   37500.0       0     Low
# 1  Pankaj   30   40000    POSCO      M  20000.0   60000.0       1    High
# 2   Madhu   23   50000     Hero      F  25000.0   75000.0       0    High
# 3     Adi   28   80000      IBM      M  40000.0  120000.0       1    High
# 4    Gitu   24   35000    Wipro      F  17500.0   52500.0       0    High
# 5  Nilesh   22   18000   School      M   9000.0   27000.0       1     Low
# 6     Mau   18   15000  College      F   7500.0   22500.0       0     Low
#
#   Initial
# 0       A
# 1       P
# 2     NaN
# 3       A
# 4     NaN
# 5       N
# 6     NaN

# %%
df.dtypes
# Out:
# Name        object
# Age          int64
# Salary       int64
# Company     object
# Gender      object
# Bonus      float64
# Total      float64
# Encode       int64
# Profile     object
# Initial     object
# dtype: object

# %%
#how to change datatypes of any column
df['DTCngAGE'] = df['Age'].astype('float64')
df
# Out:
#      Name  Age  Salary  Company Gender    Bonus     Total  Encode Profile  \
# 0  Ankita   23   25000   Amazon      F  12500.0   37500.0       0     Low
# 1  Pankaj   30   40000    POSCO      M  20000.0   60000.0       1    High
# 2   Madhu   23   50000     Hero      F  25000.0   75000.0       0    High
# 3     Adi   28   80000      IBM      M  40000.0  120000.0       1    High
# 4    Gitu   24   35000    Wipro      F  17500.0   52500.0       0    High
# 5  Nilesh   22   18000   School      M   9000.0   27000.0       1     Low
# 6     Mau   18   15000  College      F   7500.0   22500.0       0     Low
#
#   Initial  DTCngAGE
# 0       A      23.0
# 1       P      30.0
# 2     NaN      23.0
# 3       A      28.0
# 4     NaN      24.0
# 5       N      22.0
# 6     NaN      18.0

# %%
#to get complete info of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7 entries, 0 to 6
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      7 non-null      object
#  1   Age       7 non-null      int64
#  2   Salary    7 non-null      int64
#  3   Company   7 non-null      object
#  4   Gender    7 non-null      object
#  5   Bonus     7 non-null      float64
#  6   Total     7 non-null      float64
#  7   Encode    7 non-null      int64
#  8   Profile   7 non-null      object
#  9   Initial   4 non-null      object
#  10  DTCngAGE  7 non-null      float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 744.0+ bytes

# %%
df
# Out:
#      Name  Age  Salary  Company Gender    Bonus     Total  Encode Profile  \
# 0  Ankita   23   25000   Amazon      F  12500.0   37500.0       0     Low
# 1  Pankaj   30   40000    POSCO      M  20000.0   60000.0       1    High
# 2   Madhu   23   50000     Hero      F  25000.0   75000.0       0    High
# 3     Adi   28   80000      IBM      M  40000.0  120000.0       1    High
# 4    Gitu   24   35000    Wipro      F  17500.0   52500.0       0    High
# 5  Nilesh   22   18000   School      M   9000.0   27000.0       1     Low
# 6     Mau   18   15000  College      F   7500.0   22500.0       0     Low
#
#   Initial  DTCngAGE
# 0       A      23.0
# 1       P      30.0
# 2     NaN      23.0
# 3       A      28.0
# 4     NaN      24.0
# 5       N      22.0
# 6     NaN      18.0

# %%
#how to use apply function
def range(x):
    if 0<x<=25000:
        return 'Low'
    elif 25000<x<=50000:
        return 'Medium'
    else:
        return "High"

df['Range'] = df['Salary'].apply(range)
df
# Out:
#      Name  Age  Salary  Company Gender    Bonus     Total  Encode Profile  \
# 0  Ankita   23   25000   Amazon      F  12500.0   37500.0       0     Low
# 1  Pankaj   30   40000    POSCO      M  20000.0   60000.0       1    High
# 2   Madhu   23   50000     Hero      F  25000.0   75000.0       0    High
# 3     Adi   28   80000      IBM      M  40000.0  120000.0       1    High
# 4    Gitu   24   35000    Wipro      F  17500.0   52500.0       0    High
# 5  Nilesh   22   18000   School      M   9000.0   27000.0       1     Low
# 6     Mau   18   15000  College      F   7500.0   22500.0       0     Low
#
#   Initial  DTCngAGE   Range
# 0       A      23.0     Low
# 1       P      30.0  Medium
# 2     NaN      23.0  Medium
# 3       A      28.0    High
# 4     NaN      24.0  Medium
# 5       N      22.0     Low
# 6     NaN      18.0     Low

# %%
df['Allot'] = df['Gender'].apply(lambda x: 0 if x=='F' else 1)
df
# Out:
#      Name  Age  Salary  Company Gender    Bonus     Total  Encode Profile  \
# 0  Ankita   23   25000   Amazon      F  12500.0   37500.0       0     Low
# 1  Pankaj   30   40000    POSCO      M  20000.0   60000.0       1    High
# 2   Madhu   23   50000     Hero      F  25000.0   75000.0       0    High
# 3     Adi   28   80000      IBM      M  40000.0  120000.0       1    High
# 4    Gitu   24   35000    Wipro      F  17500.0   52500.0       0    High
# 5  Nilesh   22   18000   School      M   9000.0   27000.0       1     Low
# 6     Mau   18   15000  College      F   7500.0   22500.0       0     Low
#
#   Initial  DTCngAGE   Range  Allot
# 0       A      23.0     Low      0
# 1       P      30.0  Medium      1
# 2     NaN      23.0  Medium      0
# 3       A      28.0    High      1
# 4     NaN      24.0  Medium      0
# 5       N      22.0     Low      1
# 6     NaN      18.0     Low      0

# %%
df['Length'] = df['Company'].apply(lambda x: len(x))
df
# Out:
#      Name  Age  Salary  Company Gender    Bonus     Total  Encode Profile  \
# 0  Ankita   23   25000   Amazon      F  12500.0   37500.0       0     Low
# 1  Pankaj   30   40000    POSCO      M  20000.0   60000.0       1    High
# 2   Madhu   23   50000     Hero      F  25000.0   75000.0       0    High
# 3     Adi   28   80000      IBM      M  40000.0  120000.0       1    High
# 4    Gitu   24   35000    Wipro      F  17500.0   52500.0       0    High
# 5  Nilesh   22   18000   School      M   9000.0   27000.0       1     Low
# 6     Mau   18   15000  College      F   7500.0   22500.0       0     Low
#
#   Initial  DTCngAGE   Range  Allot  Length
# 0       A      23.0     Low      0       6
# 1       P      30.0  Medium      1       5
# 2     NaN      23.0  Medium      0       4
# 3       A      28.0    High      1       3
# 4     NaN      24.0  Medium      0       5
# 5       N      22.0     Low      1       6
# 6     NaN      18.0     Low      0       7

# %%
#Mean, Maximum, Minumum, Standary deviantion
a = df['Total'].mean()
print(a)
b = df['Total'].max()
print(b)
c = df['Total'].min()
print(c)
d = df['Total'].std()
print(d)
# Out:
# 56357.142857142855
# 120000.0
# 22500.0
# 33639.89977902516

# %%
df['Salary'].min()
# Out:
# 15000

# %%
df.Salary.max()
# Out:
# 80000

# %%
#if you want salary that are above mean
df['Salary'] > df['Salary'].mean()
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# 4    False
# 5    False
# 6    False
# Name: Salary, dtype: bool

# %%
#But you want it in the form of dataframe
df[df['Salary'] > df['Salary'].mean()]
# Out:
#      Name  Age  Salary Company Gender    Bonus     Total  Encode Profile  \
# 1  Pankaj   30   40000   POSCO      M  20000.0   60000.0       1    High
# 2   Madhu   23   50000    Hero      F  25000.0   75000.0       0    High
# 3     Adi   28   80000     IBM      M  40000.0  120000.0       1    High
#
#   Initial  DTCngAGE   Range  Allot  Length
# 1       P      30.0  Medium      1       5
# 2     NaN      23.0  Medium      0       4
# 3       A      28.0    High      1       3

# %%
#if you want just names of people with salary above mean
df[df['Salary'] > df['Salary'].mean()]['Name']
# Out:
# 1    Pankaj
# 2     Madhu
# 3       Adi
# Name: Name, dtype: object

# %%
#to filter data using startswith
df[df['Name'].str.startswith('A')]
# Out:
#      Name  Age  Salary Company Gender    Bonus     Total  Encode Profile  \
# 0  Ankita   23   25000  Amazon      F  12500.0   37500.0       0     Low
# 3     Adi   28   80000     IBM      M  40000.0  120000.0       1    High
#
#   Initial  DTCngAGE Range  Allot  Length
# 0       A      23.0   Low      0       6
# 3       A      28.0  High      1       3

# %%
#to filter data using startswith but we need just one column of profile
df[df['Name'].str.startswith('A')]['Profile']
# Out:
# 0     Low
# 3    High
# Name: Profile, dtype: object

# %%
df
# Out:
#      Name  Age  Salary  Company Gender    Bonus     Total  Encode Profile  \
# 0  Ankita   23   25000   Amazon      F  12500.0   37500.0       0     Low
# 1  Pankaj   30   40000    POSCO      M  20000.0   60000.0       1    High
# 2   Madhu   23   50000     Hero      F  25000.0   75000.0       0    High
# 3     Adi   28   80000      IBM      M  40000.0  120000.0       1    High
# 4    Gitu   24   35000    Wipro      F  17500.0   52500.0       0    High
# 5  Nilesh   22   18000   School      M   9000.0   27000.0       1     Low
# 6     Mau   18   15000  College      F   7500.0   22500.0       0     Low
#
#   Initial  DTCngAGE   Range  Allot  Length
# 0       A      23.0     Low      0       6
# 1       P      30.0  Medium      1       5
# 2     NaN      23.0  Medium      0       4
# 3       A      28.0    High      1       3
# 4     NaN      24.0  Medium      0       5
# 5       N      22.0     Low      1       6
# 6     NaN      18.0     Low      0       7

# %%
#concatenation in python
my_cars = {
    'Name':['BMW', 'TATA', 'Maruti', 'Volvo'],
    'Price':[1000, 3000, 5000, 10000],
    'Milage':[22, 32, 24, 42]
}
my_bikes = {
    'Name':['Honda', 'Scooty', 'Activa', 'Hero'],
    'Price':[200, 330, 488, 500],
    'Milage':[45, 34, 54, 65]
}
import pandas as pd
df1 = pd.DataFrame(my_cars)
df2 = pd.DataFrame(my_bikes)

# %%
# to add the dataframes vertically one below one
df = pd.concat([df1,df2])
df
# Out:
#      Name  Price  Milage
# 0     BMW   1000      22
# 1    TATA   3000      32
# 2  Maruti   5000      24
# 3   Volvo  10000      42
# 0   Honda    200      45
# 1  Scooty    330      34
# 2  Activa    488      54
# 3    Hero    500      65

# %%
#To make index continous
df = pd.concat([df1,df2], ignore_index= True)
df
# Out:
#      Name  Price  Milage
# 0     BMW   1000      22
# 1    TATA   3000      32
# 2  Maruti   5000      24
# 3   Volvo  10000      42
# 4   Honda    200      45
# 5  Scooty    330      34
# 6  Activa    488      54
# 7    Hero    500      65

# %%
#To add keays to data frame
df = pd.concat([df1,df2], keys = ['Cars', 'Bikes'])
df
# Out:
#            Name  Price  Milage
# Cars  0     BMW   1000      22
#       1    TATA   3000      32
#       2  Maruti   5000      24
#       3   Volvo  10000      42
# Bikes 0   Honda    200      45
#       1  Scooty    330      34
#       2  Activa    488      54
#       3    Hero    500      65

# %%
#after alloting keys we can easily access dataframes using loc functions
df.loc['Cars']
# Out:
#      Name  Price  Milage
# 0     BMW   1000      22
# 1    TATA   3000      32
# 2  Maruti   5000      24
# 3   Volvo  10000      42

# %%
#to concat the data horizontally
df = pd.concat([df1,df2], axis= 1)
df
# Out:
#      Name  Price  Milage    Name  Price  Milage
# 0     BMW   1000      22   Honda    200      45
# 1    TATA   3000      32  Scooty    330      34
# 2  Maruti   5000      24  Activa    488      54
# 3   Volvo  10000      42    Hero    500      65

# %%
#if column name is different then 
my_cars = {
    'Name':['BMW', 'TATA', 'Maruti', 'Volvo'],
    'Horsepower':[1000, 3000, 5000, 10000],
    'Rating':[22, 32, 24, 42]
}
my_bikes = {
    'BikeName':['Honda', 'Scooty', 'Activa', 'Hero'],
    'CC':[200, 330, 488, 500],
    'Milage':[45, 34, 54, 65]
}
import pandas as pd
df1 = pd.DataFrame(my_cars)
df2 = pd.DataFrame(my_bikes)
df = pd.concat([df1,df2])
df
# Out:
#      Name  Horsepower  Rating BikeName     CC  Milage
# 0     BMW      1000.0    22.0      NaN    NaN     NaN
# 1    TATA      3000.0    32.0      NaN    NaN     NaN
# 2  Maruti      5000.0    24.0      NaN    NaN     NaN
# 3   Volvo     10000.0    42.0      NaN    NaN     NaN
# 0     NaN         NaN     NaN    Honda  200.0    45.0
# 1     NaN         NaN     NaN   Scooty  330.0    34.0
# 2     NaN         NaN     NaN   Activa  488.0    54.0
# 3     NaN         NaN     NaN     Hero  500.0    65.0

# %%
#to check tyoe of any column
type(df['Name'])
# Out:
# pandas.core.series.Series

# %%
#groupby
df0 = pd.read_csv('HR.csv')
df0
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 0                    0.38             0.53               2
# 1                    0.80             0.86               5
# 2                    0.11             0.88               7
# 3                    0.72             0.87               5
# 4                    0.37             0.52               2
# ...                   ...              ...             ...
# 14994                0.40             0.57               2
# 14995                0.37             0.48               2
# 14996                0.37             0.53               2
# 14997                0.11             0.96               6
# 14998                0.37             0.52               2
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 0                       157                   3              0     1
# 1                       262                   6              0     1
# ...

# %%
obj = df0.groupby('salary')

# %%
#will give rows only with salary column with value as high
obj.get_group('high')
# Out:
#        satisfaction_level  last_evaluation  number_project  \
# 72                   0.45             0.49               2
# 111                  0.09             0.85               6
# 189                  0.44             0.51               2
# 267                  0.45             0.53               2
# 306                  0.37             0.46               2
# ...                   ...              ...             ...
# 14829                0.45             0.57               2
# 14868                0.43             0.55               2
# 14902                0.45             0.46               2
# 14941                0.43             0.49               2
# 14980                0.76             0.89               5
#
#        average_montly_hours  time_spend_company  Work_accident  left  \
# 72                      149                   3              0     1
# 111                     289                   4              0     1
# ...

# %%
df0['salary'].value_counts()
# Out:
# low       7316
# medium    6446
# high      1237
# Name: salary, dtype: int64

# %% [markdown]
# $$

# %%
import pandas as pd
Emp = [
    ('Ankita', 23, 25000, 'Amazon', 'F'),
    ('Pankaj', 30, 40000, 'POSCO', 'M'),
    ('Madhu', 23, 50000, 'Hero', 'F'),
    ('Adi', 28, 80000, 'IBM', 'M'),
    ('Gitu', 24, 35000, 'Wipro', 'F'),
    ('Nilesh', 22, 18000, 'School', 'M'),
    ('Mau', 18, 15000, 'College', 'F'),
]

df = pd.DataFrame(data = Emp, columns = ['Name', 'Age', 'Salary','Company', 'Gender'])
df['Bonus'] = df['Salary']/2
df['Total'] = df['Salary']+df['Bonus']
df
# Out:
#      Name  Age  Salary  Company Gender    Bonus     Total
# 0  Ankita   23   25000   Amazon      F  12500.0   37500.0
# 1  Pankaj   30   40000    POSCO      M  20000.0   60000.0
# 2   Madhu   23   50000     Hero      F  25000.0   75000.0
# 3     Adi   28   80000      IBM      M  40000.0  120000.0
# 4    Gitu   24   35000    Wipro      F  17500.0   52500.0
# 5  Nilesh   22   18000   School      M   9000.0   27000.0
# 6     Mau   18   15000  College      F   7500.0   22500.0

# %%
df.describe()
# Out:
#              Age        Salary         Bonus          Total
# count   7.000000      7.000000      7.000000       7.000000
# mean   24.000000  37571.428571  18785.714286   56357.142857
# std     3.958114  22426.599853  11213.299926   33639.899779
# min    18.000000  15000.000000   7500.000000   22500.000000
# 25%    22.500000  21500.000000  10750.000000   32250.000000
# 50%    23.000000  35000.000000  17500.000000   52500.000000
# 75%    26.000000  45000.000000  22500.000000   67500.000000
# max    30.000000  80000.000000  40000.000000  120000.000000

# %%
df[df.Salary>60000]
# Out:
#   Name  Age  Salary Company Gender    Bonus     Total
# 3  Adi   28   80000     IBM      M  40000.0  120000.0

# %%
import pandas as pd
df = pd.read_csv('titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.shape
# Out:
# (891, 12)

# %%
df1 = df.fillna(0)

# %%
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2 = df.dropna()

# %%
df2
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 10            11         1       3
# 11            12         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 10                     Sandstrom, Miss. Marguerite Rut  female   4.0      1
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2.shape
# Out:
# (183, 12)

# %%
df1 = pd.DataFrame([
    {'Name':'Iron', 'Id':501, 'Price':5000, 'Quantity': 10000},
    {'Name':'Gold', 'Id':110, 'Price':9050, 'Quantity': 60000},    
    {'Name':'Silver', 'Id':321, 'Price':2060, 'Quantity': 30000},
    {'Name':'Platinum', 'Id':990, 'Price':2300, 'Quantity': 20000}
])
df2 = pd.DataFrame([
    {'Name':'Iron', 'Id':501, 'At_Weight':55.845, 'At_No': 26},
    {'Name':'Copper', 'Id':235, 'At_Weight':63.546, 'At_No': 29},
    {'Name':'Gold', 'Id':110, 'At_Weight':196.966569, 'At_No': 79},
    {'Name':'Aluminium', 'Id':881, 'At_Weight':26.9815385, 'At_No': 13}
])

# %%
df1
# Out:
#        Name   Id  Price  Quantity
# 0      Iron  501   5000     10000
# 1      Gold  110   9050     60000
# 2    Silver  321   2060     30000
# 3  Platinum  990   2300     20000

# %%
df2
# Out:
#         Name   Id   At_Weight  At_No
# 0       Iron  501   55.845000     26
# 1     Copper  235   63.546000     29
# 2       Gold  110  196.966569     79
# 3  Aluminium  881   26.981538     13

# %%
df = pd.merge(df1, df2, on = 'Name', how = 'inner')
df
# Out:
#    Name  Id_x  Price  Quantity  Id_y   At_Weight  At_No
# 0  Iron   501   5000     10000   501   55.845000     26
# 1  Gold   110   9050     60000   110  196.966569     79

# %%
df = pd.merge(df1, df2, on = 'Name', how = 'outer')
df
# Out:
#         Name   Id_x   Price  Quantity   Id_y   At_Weight  At_No
# 0       Iron  501.0  5000.0   10000.0  501.0   55.845000   26.0
# 1       Gold  110.0  9050.0   60000.0  110.0  196.966569   79.0
# 2     Silver  321.0  2060.0   30000.0    NaN         NaN    NaN
# 3   Platinum  990.0  2300.0   20000.0    NaN         NaN    NaN
# 4     Copper    NaN     NaN       NaN  235.0   63.546000   29.0
# 5  Aluminium    NaN     NaN       NaN  881.0   26.981538   13.0

# %%
df = pd.merge(df1, df2, on = 'Name', how = 'left')
df
# Out:
#        Name  Id_x  Price  Quantity   Id_y   At_Weight  At_No
# 0      Iron   501   5000     10000  501.0   55.845000   26.0
# 1      Gold   110   9050     60000  110.0  196.966569   79.0
# 2    Silver   321   2060     30000    NaN         NaN    NaN
# 3  Platinum   990   2300     20000    NaN         NaN    NaN

# %%
df = pd.merge(df1, df2, on = 'Name', how = 'right')
df
# Out:
#         Name   Id_x   Price  Quantity  Id_y   At_Weight  At_No
# 0       Iron  501.0  5000.0   10000.0   501   55.845000     26
# 1     Copper    NaN     NaN       NaN   235   63.546000     29
# 2       Gold  110.0  9050.0   60000.0   110  196.966569     79
# 3  Aluminium    NaN     NaN       NaN   881   26.981538     13
